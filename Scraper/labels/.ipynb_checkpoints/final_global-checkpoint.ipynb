# %%
india_symbols = ['^INDIAVIX','^NSEI','^CNXIT']
start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2024, 3, 6)

# Function to fetch historical data for a symbol
def fetch_data(symbol):
    data = yf.download(symbol, start=start, end=end)
    return data[['Open','High','Low' ,'Close', 'Volume']].rename(columns={'Open': f'{symbol}_open','Low': f'{symbol}_low','High': f'{symbol}_high','Close': f'{symbol}_close', 'Volume': f'{symbol}_volume'})

# Fetch data for all symbols and create a DataFrame
dfs = [fetch_data(symbol) for symbol in india_symbols]
result_df = pd.concat(dfs, axis=1, join='inner')

# Print the resulting DataFrame
print(result_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['^INDIAVIX']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Empty DataFrame
# Columns: [^INDIAVIX_open, ^INDIAVIX_high, ^INDIAVIX_low, ^INDIAVIX_close, ^INDIAVIX_volume, ^NSEI_open, ^NSEI_high, ^NSEI_low, ^NSEI_close, ^NSEI_volume, ^CNXIT_open, ^CNXIT_high, ^CNXIT_low, ^CNXIT_close, ^CNXIT_volume]
# Index: []

# %%
fetch_data('^CNXIT - NIFTY IT.')
# Out:
# [*********************100%%**********************]  4 of 4 completed
#
# 3 Failed downloads:
# ['NIFTY', '-', 'IT.']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Price      ^CNXIT - NIFTY IT._open                          \
# Ticker                           - IT. NIFTY        ^CNXIT
# Date
# 2018-01-02                     NaN NaN   NaN  11587.849609
# 2018-01-03                     NaN NaN   NaN  11617.349609
# 2018-01-04                     NaN NaN   NaN  11599.049805
# 2018-01-05                     NaN NaN   NaN  11575.450195
# 2018-01-08                     NaN NaN   NaN  11674.349609
# ...                            ...  ..   ...           ...
# 2024-02-28                     NaN NaN   NaN  37926.648438
# 2024-02-29                     NaN NaN   NaN  37616.199219
# 2024-03-01                     NaN NaN   NaN  37823.699219
# 2024-03-04                     NaN NaN   NaN  37634.250000
# 2024-03-05                     NaN NaN   NaN  37180.050781
#
# Price      ^CNXIT - NIFTY IT._high                          \
# Ticker                           - IT. NIFTY        ^CNXIT
# Date
# 2018-01-02                     NaN NaN   NaN  11655.500000
# 2018-01-03                     NaN NaN   NaN  11693.349609
# 2018-01-04                     NaN NaN   NaN  11607.750000
# 2018-01-05                     NaN NaN   NaN  11691.450195
# 2018-01-08                     NaN NaN   NaN  11793.849609
# ...                            ...  ..   ...           ...
# 2024-02-28                     NaN NaN   NaN  38138.351562
# 2024-02-29                     NaN NaN   NaN  37896.050781
# 2024-03-01                     NaN NaN   NaN  37888.851562
# 2024-03-04                     NaN NaN   NaN  37733.250000
# 2024-03-05                     NaN NaN   NaN  37202.300781
#
# Price      ^CNXIT - NIFTY IT._low                          \
# Ticker                          - IT. NIFTY        ^CNXIT
# Date
# 2018-01-02                    NaN NaN   NaN  11558.450195
# 2018-01-03                    NaN NaN   NaN  11573.250000
# 2018-01-04                    NaN NaN   NaN  11510.400391
# 2018-01-05                    NaN NaN   NaN  11541.799805
# 2018-01-08                    NaN NaN   NaN  11661.500000
# ...                           ...  ..   ...           ...
# 2024-02-28                    NaN NaN   NaN  37594.500000
# 2024-02-29                    NaN NaN   NaN  37414.949219
# 2024-03-01                    NaN NaN   NaN  37462.851562
# 2024-03-04                    NaN NaN   NaN  37279.449219
# 2024-03-05                    NaN NaN   NaN  36613.101562
#
# Price      ^CNXIT - NIFTY IT._close                          \
# Ticker                            - IT. NIFTY        ^CNXIT
# Date
# 2018-01-02                      NaN NaN   NaN  11602.349609
# 2018-01-03                      NaN NaN   NaN  11586.700195
# 2018-01-04                      NaN NaN   NaN  11590.799805
# 2018-01-05                      NaN NaN   NaN  11633.549805
# 2018-01-08                      NaN NaN   NaN  11776.849609
# ...                             ...  ..   ...           ...
# 2024-02-28                      NaN NaN   NaN  37741.750000
# 2024-02-29                      NaN NaN   NaN  37720.398438
# 2024-03-01                      NaN NaN   NaN  37516.050781
# 2024-03-04                      NaN NaN   NaN  37314.800781
# 2024-03-05                      NaN NaN   NaN  36720.750000
#
# Price      ^CNXIT - NIFTY IT._volume
# Ticker                             - IT. NIFTY ^CNXIT
# Date
# 2018-01-02                       NaN NaN   NaN      0
# 2018-01-03                       NaN NaN   NaN      0
# 2018-01-04                       NaN NaN   NaN      0
# 2018-01-05                       NaN NaN   NaN      0
# 2018-01-08                       NaN NaN   NaN      0
# ...                              ...  ..   ...    ...
# 2024-02-28                       NaN NaN   NaN  14800
# 2024-02-29                       NaN NaN   NaN  26400
# 2024-03-01                       NaN NaN   NaN  18800
# 2024-03-04                       NaN NaN   NaN  14500
# 2024-03-05                       NaN NaN   NaN  18100
#
# [1516 rows x 20 columns]

# %%
import yfinance as yf
import datetime
import pandas as pd

# Define symbols, start, and end dates
symbols = ['^DJI', 'BTC-USD', 'ETH-USD', 'CL=F', 'GC=F', 'SI=F', 'NG=F', 'DX-Y.NYB', '^BSESN', '^NDX', '^GSPC', '^NSEI']
start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2024, 3, 6)

# Function to fetch historical data for a symbol
def fetch_data(symbol):
    data = yf.download(symbol, start=start, end=end)
    return data[['Open','High','Low' ,'Close', 'Volume']].rename(columns={'Open': f'{symbol}_open','Low': f'{symbol}_low','High': f'{symbol}_high','Close': f'{symbol}_close', 'Volume': f'{symbol}_volume'})

# Fetch data for all symbols and create a DataFrame
dfs = [fetch_data(symbol) for symbol in symbols]
result_df = pd.concat(dfs, axis=1, join='inner')

# Print the resulting DataFrame
print(result_df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

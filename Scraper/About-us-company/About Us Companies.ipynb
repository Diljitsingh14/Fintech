# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime,timedelta
import pandas as pd
import re
import numpy as np

# %%
host = 'https://www.moneycontrol.com'
base_url = 'https://www.moneycontrol.com/stocks/marketstats/industry-classification/bse/abrasives.html'
about_us_data = []
industries = []

data_struct = {
    'Name':"",
    "Sector":"",
    "Link":"",
    "Website":"",
    "About us":""
}

# %%
# Function to fech infomations

def get_company_info(link,d=data_struct.copy()):
    """
    Fetch the infomation about company  and return Comp sturct
    """
    
    headers = {'Accept-Encoding': 'gzip'}
    response = requests.get(link,headers=headers)
    if(response.status_code != 200):
        return
    comp_soup =  BeautifulSoup(response.text,'html.parser')
    name = comp_soup.find('div',{"id":"stockName"}).find("h1").text
    about_us  = comp_soup.find('div',{"id":"company_info"})
    info_div = about_us.find("div",{"class":"morepls_cnt"})
    if info_div:
        d['About us'] = info_div.text
    comp_links = about_us.find("ul",{'class':"comdetl"}).find_all('a')
    if len(comp_links) > 0:
        d['Website'] = comp_links[-1]['href']
        
    d['Name']=name
    d['Link'] = link
    
    return d

def get_companies_in_sector(industry_link,industry_name=""):
    """
    Fetch compaines in specific industry
    """
    
    i_data = []
    response = requests.get(industry_link)
    print(f"------------------------{industry_name}-------------------")
    comp_in_sectors_soup =  BeautifulSoup(response.text,'html.parser')  
    for com in comp_in_sectors_soup.find('div',{"class":"ReuseTable_bsr_table__eVZZf"}).find('tbody').children:
        d = data_struct.copy()
        anker = com.find('td').find('a')
        print(anker.text)
        com_link = anker['href']
        d['Sector'] = industry_name
        comp_data = get_company_info(com_link,d)
        if(comp_data):
            i_data.append(comp_data)
    return i_data

def fetch_industries_link():
    """
    Fetch list of industries
    """
    
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text,'html.parser')  

    for index,li in enumerate(soup.find("ul",{"class":"IndustryWeb_stat_lflist__Colzh"}).children):
            industry_data = {}
            industry_data['name'] = li.text
            industry_data['link'] = f"{host}{li.find('a')['href']}"
            industries.append(industry_data)

# %%
fetch_industries_link
industries[:10]
# Out:
# [{'name': 'Abrasives',
#   'link': 'https://www.moneycontrol.com/stocks/marketstats/industry-classification/bse/abrasives.html'},
#  {'name': 'Aerospace & Defence',
#   'link': 'https://www.moneycontrol.com/stocks/marketstats/industry-classification/bse/aerospace-defence.html'},
#  {'name': 'Agriculture',
#   'link': 'https://www.moneycontrol.com/stocks/marketstats/industry-classification/bse/agriculture.html'},
#  {'name': 'Air Conditioners',
#   'link': 'https://www.moneycontrol.com/stocks/marketstats/industry-classification/bse/air-conditioners.html'},
#  {'name': 'Airlines',
#   'link': 'https://www.moneycontrol.com/stocks/marketstats/industry-classification/bse/airlines.html'},
#  {'name': 'Aluminium & Aluminium Products',
#   'link': 'https://www.moneycontrol.com/stocks/marketstats/industry-classification/bse/aluminium-aluminium-products.html'},
#  {'name': 'Amusement Parks/Recreation/Club',
#   'link': 'https://www.moneycontrol.com/stocks/marketstats/industry-classification/bse/amusement-parksrecreationclub.html'},
#  {'name': 'Aquaculture',
#   'link': 'https://www.moneycontrol.com/stocks/marketstats/industry-classification/bse/aquaculture.html'},
#  {'name': 'Auto Ancillaries',
#   'link': 'https://www.moneycontrol.com/stocks/marketstats/industry-classification/bse/auto-ancillaries.html'},
#  {'name': 'Auto Ancillaries - Air Conditioning Parts',
#   'link': 'https://www.moneycontrol.com/stocks/marketstats/industry-classification/bse/auto-ancillaries-air-conditioning-parts.html'}]

# %%
# fetch companies in industries.

for i in industries[170:]:
    companies_data = get_companies_in_sector(i['link'],i['name'])
    about_us_data.append(companies_data)
# Out:
# ------------------------Software-------------------
# 63 Moons Tech
# 7Seas Tech
# AAA
# ABM Knowledg
# Acceleratebs
# Accelya
# Ace Soft Export
# Adjia Tech
# Advent Computer
# Ahasolar Tech
# Airan
# Archana Soft
# Aurionpro Solut
# Baron Infotech
# Brightcom Group
# C. E. Info Syst
# California Soft
# Canarys Automat
# Ceinsys Tech
# Cigniti Tech
# CMS Info System
# COMP-RE
# Compucom Soft
# Cura Tech
# Dion Global
# DRC Systems
# Eco Recycling
# FIRST FINTEC
# Funny Software
# GISO-RE
# Globalspace Tec
# GSS Infotech
# Hit Kit Global
# Hypersoft Techn
# Indo Pacific
# InfoBeans Tech
# Infronics Syst
# Intense Tech
# IRIS Business S
# Jointeca Edu
# Kashyap Tele
# KSolves
# Lee and Nee
# Magellanic
# Melstar Info
# Mindteck
# Moschip Tech
# Nazara
# Netvista Info
# Newgen Software
# NINtec SYSTEMS
# Nucleus Softwar
# Odyssey Tech
# Olatech Solutio
# Omega Int Tech
# Omni Axs Soft
# OnMobile Global
# ORCHASP
# Parle  Indus
# PFL Infotech
# Prithvi Exc
# PS IT Infra
# Ram Informatics
# Ramco System
# Rategain Travel
# RS Software
# Saksoft
# Sancode Tech
# Silicon Rental
# Silver Touch Te
# SIT
# Softtech Engine
# Subex
# Svam Software
# Tanla Platforms
# Tata Elxsi
# TechNVision
# Tracxn Tech
# Trejhara
# Twinstar Ind
# Veefin Solution
# Virinchi
# WEP SOLN-RE
# Wherrelz IT
# ------------------------Solvent  Extraction-------------------
# IEL
# ------------------------Speciality Chemicals-------------------
# Aadi Industries
# Aarti Ind
# Aether Ind
# Alkyl Amines
# Amal
# AMI Organics
# Anupam Rasayan
# Apcotex Ind
# Asian Petro
# Atul
# AVI Polymers
# Balaji Amines
# Bhatia Colour
# Black Rose Ind
# Camlin Fine
# Chembond Chem
# Chemcon Special
# Chemcrux Enterp
# CHEMPLAST SANMA
# Chromatic India
# CJ Gelatine
# Clean Science
# Cochin Minerals
# Crestchem
# Dai-Ichi Karkar
# Daikaffil Chem
# DIC India
# DMCC
# Epigral
# Fairchem Org.
# Fineotex Chem
# Foseco India
# Guj Heavy Chem
# Gujarat Fluoro
# Hardcastle
# Hemo Organic
# HEUBACHIND
# Hind Flurocarbo
# IG Petro
# India Gelatine
# Indo Amines
# Indokem
# Jayant Agro-Org
# Jubilant Ing.
# Jyoti Resins
# Kanoria Chem
# KELTECH Energ
# Kemistar Corp
# Laxmi Organic
# Manali Petro
# Multibase India
# Narmada Gelatin
# Navin Fluorine
# Neogen
# Nitta Gelatin
# Omkar Special
# Paushak Ltd
# Plastiblends
# Polson
# Privi Special
# Ram Minerals
# Rossari
# Seya Industries
# Supreme Petro
# Tatva Chintan
# Tinna Rubber an
# Titan Biotech
# Ultramarine
# Vikas Ecotech
# Vikas WSP
# Vinati Organics
# Vinyl Chemicals
# Starlog Enter
# ------------------------Travel Services-------------------
# Asya Infosoft
# BLS Internation
# Cox & Kings
# Easy Trip
# FAMILY-RE
# Growington Vent
# Intl Travel
# Mahasagar Trav
# Thomas Cook
# Trade Wings
# Transcorp Intl
# Yaan Enterprise
# Yatra Online
# ------------------------TV Broadcasting & Software Production-------------------
# Bodhi Tree Mult
# Colorchips New
# Creative Eye
# Diksat Transwor
# Ent Network Ind
# HAZOOR-RE
# Inspire Films
# Jain Studios
# Landmarc Corp
# Maagh Advertisi
# Music Broadcast
# NDL Ventures
# NDTV
# Network 18
# Ortel Comm
# Padmalaya Tele
# Perfect-Octave
# Raj Television
# Sadhna Broadcas
# Sea TV Network
# Siti Networks
# Sun TV Network
# Trilogic Digi
# TV TodayNetwork
# TV Vision
# TV18 Broadcast
# Zee Entertain
# Zee Media
# ------------------------Vegetable Oils & Products-------------------
# Agro Tech Foods
# Ajanta Soya
# Ashiana Agro
# AVT Natural
# BCL Industries
# Diligent Ind
# Divya Jyoti Ind
# Evexia Lifecare
# Gokul Agro
# Gokul Refoils
# Integ Proteins
# J R Foods Ltd
# JVL Agro Ind
# Kriti Nutrients
# M K Proteins
# Madhusudan Ind
# Manorama Indust
# Modi Naturals
# Natraj Proteins
# NK Industries
# Oasis Tradelink
# Olympic Oil Ind
# Paos Industries
# Patanjali Foods
# Pioneer Agro
# Poona Dal
# Prima Ind
# Prime Industrie
# Raj Oil Mills
# Rasoi
# Rasoya Protein
# Ruchinfra
# Sagar Soya
# Sanwaria Consum
# Superior Ind
# Vijay Solvex
# Vimal Oils
# WARDWIZFBL
# ------------------------Watches & Accessories-------------------
# Ethos
# KDDL
# Timex Group Ind
# ------------------------Wood & Wood Products-------------------
# Archidply Decor
# Archidply Ind
# Bloom Dekor
# CenturyPlyboard
# Duroply Industr
# Ecoboard Inds
# Greenpanel Ind
# Greenply Ind
# Mangalam Timber
# Milestone Furni
# Oriental RI
# Pratik Panels
# Rushil Decor
# Uniply Decor

# %%
# Shape of all dfs 
len(about_us_data)
# len(industries)
# len(about_us_data[-1])
# about_us_data[-1]
# Out:
# 192

# %%
# Reshape 
full_data = []
for i in about_us_data:
    for com  in i:
        full_data.append(com)

# %%
# save fetched data
about_us_df = pd.DataFrame(full_data)
about_us_df.to_csv("about_us_company.csv",index=False)
industry_df = pd.DataFrame(industries)
industry_df.to_csv("about_us.csv",index=False)

# %%
get_company_info('https://www.moneycontrol.com/india/stockpricequote/printingstationery/tcplpackaging/TCP01')

# %%
get_companies_in_sector(industry_link,"Abrasives")

# %% [markdown]
# #### Data exploration

# %%
about_us_df['char_len'] = about_us_df['About us'].apply(lambda text: len(text))

# %%
about_us_df.describe()
# Out:
#           char_len
# count  4714.000000
# mean    365.401994
# std     313.845734
# min       0.000000
# 25%      90.000000
# 50%     331.000000
# 75%     547.000000
# max    1929.000000

# %%
(about_us_df['char_len'] == 0).value_counts()
# Out:
# False    3592
# True     1122
# Name: char_len, dtype: int64

# %%
about_us_df.duplicated()
# Out:
# False    4714
# dtype: int64

# %%
about_us_df[about_us_df['char_len'] == 0].iloc[2]['Link']
# Out:
# 'https://www.moneycontrol.com/india/stockpricequote/aerospace-defence/dreamfolksservices/DS09'
